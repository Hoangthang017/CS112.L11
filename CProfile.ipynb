# %% [markdown]
# <a href="https://colab.research.google.com/github/Hoangthang017/CS112.L11/blob/master/CProfile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def LuyThua(a, b):
    if(b == 1):
        return a%1000000007
    else:
        x = LuyThua(a,b//2)
        x = x**2
        if (b%2 == 1):
            x = x*a
    return x%1000000007

# %%
a = []
def AVL(a, low, high):
    if (high >= low):
        mid = (low + high) // 2
        AVL(a, low, mid-1)
        AVL(a, mid+1, high)
AVL(a, 0, len(a)-1)

# %%
import time
import csv
import random
import numpy as np
import cProfile

# %%
for i in range(30):
  n = 10*i
  Arr = np.arange(n)
  cProfile.run('for i in range(100000): AVL(Arr, 0, n-1)')
# Out:
#          100003 function calls in 0.031 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    100000    0.009    0.000    0.009    0.000 <ipython-input-4-20c610e725b6>:2(AVL)
#         1    0.022    0.022    0.031    0.031 <string>:1(<module>)
#         1    0.000    0.000    0.031    0.031 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
#          2100003 function calls (100003 primitive calls) in 0.545 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
# 2100000/100000    0.523    0.000    0.523    0.000 <ipython-input-4-20c610e725b6>:2(AVL)
#         1    0.022    0.022    0.545    0.545 <string>:1(<module>)
#         1    0.000    0.000    0.545    0.545 {built-in method builtins.exec}
# ...
